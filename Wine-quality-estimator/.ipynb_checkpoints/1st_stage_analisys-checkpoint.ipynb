# %% [markdown]
# <h1 align=center><font size = 6><b>The good, the bad and the data wine</b></font></h1>

# %% [markdown]
# <h3 align=center><font size = 3><b>A project by Boris Y. Nedyalkov</b></font></h3>
# <h3 align=center><font size = 3>With data from https://archive.ics.uci.edu/ml/datasets/wine+quality</font></h3>

# %% [markdown]
# <center> <img src="https://t3.gstatic.com/licensed-image?q=tbn:ANd9GcQUeapVVwUmTQ7Zjx4lvffOfrgGENEh9-rSPwDbov6J_Z9l2yJWxSemTPhUkGLX5vAw" width=700, height=700 /></center>

# %% [markdown]
# Some explanation about the project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
df = pd.read_csv("winequality-red.csv")

# %% [markdown]
# ## *Exploring the data*

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(df.corr(), 
        xticklabels=df.corr().columns,
        yticklabels=df.corr().columns)
# Out:
# <AxesSubplot: >

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
pd.plotting.scatter_matrix(df, figsize=(12, 8))
# Out:
# array([[<AxesSubplot: xlabel='fixed acidity', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='volatile acidity', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='citric acid', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='residual sugar', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='chlorides', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='free sulfur dioxide', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='total sulfur dioxide', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='density', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='pH', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='sulphates', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='alcohol', ylabel='fixed acidity'>,
#         <AxesSubplot: xlabel='quality', ylabel='fixed acidity'>],
#        [<AxesSubplot: xlabel='fixed acidity', ylabel='volatile acidity'>,
# ...

# %%
# notes
# fixed acid vs citric acid - slight linear relationship
# fixed acid vs density - slight linear relationship
# fixed acid vs pH - slight linear relationship
# alchohol show a poisson - check the median and deviation

# Most correlated with quality  !!!! cancel - the 'quality' is gaussian imbalanced
# citric acid - check the median and deviation
# sulphates - check the median and deviation            
# alcohol - check the median and deviation     

# chlorides vs quality show a good distribution - check the distribution

# %%
df['quality'].value_counts().sum()
# Out:
# 1599

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
sns.histplot(df['quality'])
# Out:
# <AxesSubplot: xlabel='quality', ylabel='Count'>

# %%
graph1 = sns.barplot(x='quality', y='chlorides', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
# graph1.axhline(1.0, linestyle="dashed")
plt.show()

# %%
for i in range(1,12):
    print (i,i//3, i%3)
# Out:
# 1 0 1
# 2 0 2
# 3 1 0
# 4 1 1
# 5 1 2
# 6 2 0
# 7 2 1
# 8 2 2
# 9 3 0
# 10 3 1
# 11 3 2

# %%
fig, axes = plt.subplots(3, 4, figsize=(16,8))
fig.suptitle('Wine anaylisis barplots')

i = 0
for col in df.columns:
    sns.barplot(ax = axes[i//4,i%4], x='quality', y=col, data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
    i = i + 1
    # graph1.axhline(1.0, linestyle="dashed")

# %% [markdown]
# ## Notes
#
# #### **Features of the wine showing**:
#
# * **No relation to the quality**:
#     * fixed acidity, residiual sugar
# <br/><br/>
# * **To be examined further**:
#     * density
#     * pH
# <br/><br/>
# * **Uncertain relation to the quality**:
#     * citric acid - somewhat of an upward trend vs quality (variance is a bit high though) - SHOW
#     * free sulfur dioxide - there could be a trend, but the variance is too high
#     * density - there could be small variations - checked (there could be a trend but variance too high)
#     * pH - big var but there could be something - SCK
# <br/><br/>
# * **More certain relation to the quality**:
#     * volatile acidity - clear downward trend vs quality - SHOW
#     * chlorides - the variation in the chlorides gets linearly lower with the increase of wine quality - SHOW
#     * sulfates - good upward trend, though var swh high - SHOW
#     * alchohol - slight but defined upward trend - SHOW

# %%
sns.barplot(x='quality', y='density', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)
plt.yscale('log')

# %%
sns.barplot(x='quality', y='pH', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)
plt.yscale('log')

# %%
fig, axes = plt.subplots(3, 2, figsize=(16,8))
fig.suptitle('Wine anaylisis barplots')

sns.barplot(ax = axes[0,0], x='quality', y='citric acid', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
sns.barplot(ax = axes[0,1], x='quality', y='volatile acidity', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
sns.barplot(ax = axes[1,1], x='quality', y='chlorides', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
sns.barplot(ax = axes[1,0], x='quality', y='sulphates', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
sns.barplot(ax = axes[2,1], x='quality', y='alcohol', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)
# Out:
# <AxesSubplot: xlabel='quality', ylabel='alcohol'>

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='quality', y='alcohol', data=df, linewidth=3) 
plot.set_xlabel("Quality",fontsize=25)
plot.set_ylabel("Alcohol",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='quality', y='volatile acidity', data=df, linewidth=3) 
plot.set_xlabel("Quality",fontsize=25)
plot.set_ylabel("Volatile acidity",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
# make pie chard with High, Mid and Low graded wines value counts

# %%
df_quality = df['quality'].value_counts()
df_quality = df_quality.to_frame()
df_quality.reset_index(inplace=True)
df_quality.rename(columns={'index':'class'}, inplace=True)
df_quality.rename(columns={'quality':'number_of_wines'}, inplace=True)
df_quality.rename(columns={'class':'quality'}, inplace=True)
df_quality.sort_values(by=['quality'], inplace=True)
df_quality
# Out:
#    quality  number_of_wines
# 5        3               10
# 3        4               53
# 0        5              681
# 1        6              638
# 2        7              199
# 4        8               18

# %%
plt.figure(figsize=(7, 6), dpi=100) # width and height in inches
plot = sns.barplot(y=df_quality.iloc[:,0], x=df_quality.iloc[:,1], orient='h')  
plot.set_xlabel("Number of wines",fontsize=25)
plot.set_ylabel("Quality grade",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
wine_marks = {'Low':[df_quality.iloc[0,1]+df_quality.iloc[1,1]],'Medium':[df_quality.iloc[2,1]+df_quality.iloc[3,1]],'High':[df_quality.iloc[4,1]+df_quality.iloc[5,1]]}
wine_marks = {'Quality':['Low','Medium','High'], 'Amount':[df_quality.iloc[0,1]+df_quality.iloc[1,1], df_quality.iloc[2,1]+df_quality.iloc[3,1], df_quality.iloc[4,1]+df_quality.iloc[5,1]]}
wine_marks
# df_quality[]
# Out:
# {'Quality': ['Low', 'Medium', 'High'], 'Amount': [63, 1319, 217]}

# %%
df_quality_generalized = pd.DataFrame(data=wine_marks)
df_quality_generalized.iloc[:,0]
# Out:
# 0       Low
# 1    Medium
# 2      High
# Name: Quality, dtype: object

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi = 50)

patches, texts, pcts = ax.pie(df_quality_generalized.iloc[:,1], labels=df_quality_generalized.iloc[:,0], autopct='%.1f%%',
    wedgeprops={'linewidth': 2.5, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=-12)
# For each wedge, set the corresponding text label color to the wedge's
# face color.
for i, patch in enumerate(patches):
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax.set_title('Wine Quality Distribution', fontsize=20)
plt.tight_layout()
plt.savefig('foo.png', transparent=True, bbox_inches='tight')

# %%
plt.figure(figsize=(12, 6), dpi=50) # width and height in inches
plot = sns.barplot(x='quality', y='chlorides', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean) 
plot.set_xlabel("Quality",fontsize=25)
plot.set_ylabel("Chlorides",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=50) # width and height in inches
plot = sns.barplot(x='quality', y='sulphates', data=df, errorbar = "sd", capsize = 0.1, estimator=np.mean)
plot.set_xlabel("Quality",fontsize=25)
plot.set_ylabel("Sulphates",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18, 6), dpi=100)
sns.kdeplot(
   data=df, x="sulphates", hue="quality",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot: xlabel='sulphates', ylabel='Density'>

# %%
fig, axes = plt.subplots(3, 4, figsize=(16,8))
fig.suptitle('Wine anaylisis barplots')

i = 0
for col in df.columns:
    sns.kdeplot(ax = axes[i//4,i%4],
       data=df, x=col, hue="quality",
       fill=True, common_norm=False, palette="crest",
       alpha=.5, linewidth=0, warn_singular=False
    )
    i = i + 1
    
fig.tight_layout()

# %%
plt.figure(figsize=(8, 5), dpi=100)
plot = sns.kdeplot(
   data=df, x="alcohol", hue="quality",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
plot.set_xlabel("Alcohol",fontsize=18)
plot.set_ylabel("Density distribution ",fontsize=18)
plot.tick_params(labelsize=13)
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()
