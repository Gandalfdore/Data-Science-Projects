# %% [markdown]
# <h1 align=center><font size = 6><b>Used phones price estimation</b></font></h1>

# %% [markdown]
# <h3 align=center><font size = 3><b>A project by Boris Y. Nedyalkov</b></font></h3>
# <h3 align=center><font size = 3>With data from https://www.kaggle.com/datasets/ahsan81/used-handheld-device-data?resource=download</font></h3>

# %% [markdown]
# <center> <img src="https://thumbs.dreamstime.com/b/smartphones-mobile-phones-tablet-computers-creative-abstract-mobility-digital-wireless-communication-technology-business-126155999.jpg" width=700, height=700 /></center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("used_device_data.csv")

# %% [markdown]
# ## Data overlook stage

# %%
df
# Out:
#      device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0           Honor  Android        14.50  yes   no            13.0
# 1           Honor  Android        17.30  yes  yes            13.0
# 2           Honor  Android        16.69  yes  yes            13.0
# 3           Honor  Android        25.50  yes  yes            13.0
# 4           Honor  Android        15.32  yes   no            13.0
# ...           ...      ...          ...  ...  ...             ...
# 3449         Asus  Android        15.34  yes   no             NaN
# 3450         Asus  Android        15.24  yes   no            13.0
# 3451      Alcatel  Android        15.80  yes   no            13.0
# 3452      Alcatel  Android        15.80  yes   no            13.0
# 3453      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0                 5.0             64.0  3.0   3020.0   146.0          2020
# 1                16.0            128.0  8.0   4300.0   213.0          2020
# 2                 8.0            128.0  8.0   4200.0   213.0          2020
# 3                 8.0             64.0  6.0   7250.0   480.0          2020
# 4                 8.0             64.0  3.0   5000.0   185.0          2020
# ...               ...              ...  ...      ...     ...           ...
# 3449              8.0             64.0  6.0   5000.0   190.0          2019
# 3450              8.0            128.0  8.0   4000.0   200.0          2018
# 3451              5.0             32.0  3.0   4000.0   165.0          2020
# 3452              5.0             32.0  2.0   4000.0   160.0          2020
# 3453              5.0             16.0  2.0   4000.0   168.0          2020
#
#       days_used  normalized_used_price  normalized_new_price
# 0           127               4.307572              4.715100
# 1           325               5.162097              5.519018
# 2           162               5.111084              5.884631
# 3           345               5.135387              5.630961
# 4           293               4.389995              4.947837
# ...         ...                    ...                   ...
# 3449        232               4.492337              6.483872
# 3450        541               5.037732              6.251538
# 3451        201               4.357350              4.528829
# 3452        149               4.349762              4.624188
# 3453        176               4.132122              4.279994
#
# [3454 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   device_brand           3454 non-null   object
#  1   os                     3454 non-null   object
#  2   screen_size            3454 non-null   float64
#  3   4g                     3454 non-null   object
#  4   5g                     3454 non-null   object
#  5   rear_camera_mp         3275 non-null   float64
#  6   front_camera_mp        3452 non-null   float64
#  7   internal_memory        3450 non-null   float64
#  8   ram                    3450 non-null   float64
#  9   battery                3448 non-null   float64
#  10  weight                 3447 non-null   float64
#  11  release_year           3454 non-null   int64
#  12  days_used              3454 non-null   int64
#  13  normalized_used_price  3454 non-null   float64
#  14  normalized_new_price   3454 non-null   float64
# dtypes: float64(9), int64(2), object(4)
# memory usage: 404.9+ KB

# %%
# applying de-normalization of the prices to see the real price (in USD)
df['used_price'] = 67.91*df['normalized_used_price']
df['new_price'] = 67.91*df['normalized_new_price']

# %%
# get some statistics on the dataset
df.describe()
# Out:
#        screen_size  rear_camera_mp  front_camera_mp  internal_memory  \
# count  3454.000000     3275.000000      3452.000000      3450.000000
# mean     13.713115        9.460208         6.554229        54.573099
# std       3.805280        4.815461         6.970372        84.972371
# min       5.080000        0.080000         0.000000         0.010000
# 25%      12.700000        5.000000         2.000000        16.000000
# 50%      12.830000        8.000000         5.000000        32.000000
# 75%      15.340000       13.000000         8.000000        64.000000
# max      30.710000       48.000000        32.000000      1024.000000
#
#                ram      battery       weight  release_year    days_used  \
# count  3450.000000  3448.000000  3447.000000   3454.000000  3454.000000
# mean      4.036122  3133.402697   182.751871   2015.965258   674.869716
# std       1.365105  1299.682844    88.413228      2.298455   248.580166
# min       0.020000   500.000000    69.000000   2013.000000    91.000000
# 25%       4.000000  2100.000000   142.000000   2014.000000   533.500000
# 50%       4.000000  3000.000000   160.000000   2015.500000   690.500000
# 75%       4.000000  4000.000000   185.000000   2018.000000   868.750000
# max      12.000000  9720.000000   855.000000   2020.000000  1094.000000
#
#        normalized_used_price  normalized_new_price   used_price    new_price
# count            3454.000000           3454.000000  3454.000000  3454.000000
# mean                4.364712              5.233107   296.407597   355.380308
# std                 0.588914              0.683637    39.993124    46.425778
# min                 1.536867              2.901422   104.368653   197.035540
# 25%                 4.033931              4.790342   273.944244   325.312115
# 50%                 4.405133              5.245892   299.152556   356.248515
# 75%                 4.755700              5.673718   322.959588   385.302206
# max                 6.619433              7.847841   449.525695   532.946859

# %%
df['screen_size'].isnull().sum()
# Out:
# 0

# %%
#removing the tablets (so we just get phone data)
df['screen_size'] = df['screen_size'].apply(lambda x: x if x <= 20.5 else 'NaN')
df['screen_size'] = df['screen_size'].replace('NaN', np.nan)

# %%
df['screen_size'].isnull().sum()
# Out:
# 142

# %%
df.describe(include=['object'])
# Out:
#        device_brand       os    4g    5g
# count          3454     3454  3454  3454
# unique           34        4     2     2
# top          Others  Android   yes    no
# freq            502     3214  2335  3302

# %%
df.corr()
# Out:
# C:\Users\Smelly_Giraffe\AppData\Local\Temp\ipykernel_16808\1134722465.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                        screen_size  rear_camera_mp  front_camera_mp  \
# screen_size               1.000000        0.280873         0.435874
# rear_camera_mp            0.280873        1.000000         0.429264
# front_camera_mp           0.435874        0.429264         1.000000
# internal_memory           0.093639        0.018766         0.296426
# ram                       0.365057        0.260802         0.477411
# battery                   0.769483        0.248563         0.369709
# weight                    0.744652       -0.087738        -0.004997
# release_year              0.492757        0.353728         0.690942
# days_used                -0.394536       -0.144672        -0.552636
# normalized_used_price     0.645573        0.587302         0.608074
# normalized_new_price      0.476937        0.541655         0.475479
# used_price                0.645573        0.587302         0.608074
# new_price                 0.476937        0.541655         0.475479
#
#                        internal_memory       ram   battery    weight  \
# screen_size                   0.093639  0.365057  0.769483  0.744652
# rear_camera_mp                0.018766  0.260802  0.248563 -0.087738
# front_camera_mp               0.296426  0.477411  0.369709 -0.004997
# internal_memory               1.000000  0.122496  0.117736  0.014948
# ram                           0.122496  1.000000  0.280740  0.089916
# battery                       0.117736  0.280740  1.000000  0.703388
# weight                        0.014948  0.089916  0.703388  1.000000
# release_year                  0.235429  0.314203  0.488660  0.071290
# days_used                    -0.242712 -0.280066 -0.370895 -0.067470
# normalized_used_price         0.190993  0.520289  0.613619  0.382354
# normalized_new_price          0.195992  0.532056  0.470754  0.269540
# used_price                    0.190993  0.520289  0.613619  0.382354
# new_price                     0.195992  0.532056  0.470754  0.269540
#
#                        release_year  days_used  normalized_used_price  \
# screen_size                0.492757  -0.394536               0.645573
# rear_camera_mp             0.353728  -0.144672               0.587302
# front_camera_mp            0.690942  -0.552636               0.608074
# internal_memory            0.235429  -0.242712               0.190993
# ram                        0.314203  -0.280066               0.520289
# battery                    0.488660  -0.370895               0.613619
# weight                     0.071290  -0.067470               0.382354
# release_year               1.000000  -0.750390               0.509790
# days_used                 -0.750390   1.000000              -0.358264
# normalized_used_price      0.509790  -0.358264               1.000000
# normalized_new_price       0.303689  -0.216625               0.834496
# used_price                 0.509790  -0.358264               1.000000
# new_price                  0.303689  -0.216625               0.834496
#
#                        normalized_new_price  used_price  new_price
# screen_size                        0.476937    0.645573   0.476937
# rear_camera_mp                     0.541655    0.587302   0.541655
# front_camera_mp                    0.475479    0.608074   0.475479
# internal_memory                    0.195992    0.190993   0.195992
# ram                                0.532056    0.520289   0.532056
# battery                            0.470754    0.613619   0.470754
# weight                             0.269540    0.382354   0.269540
# release_year                       0.303689    0.509790   0.303689
# days_used                         -0.216625   -0.358264  -0.216625
# normalized_used_price              0.834496    1.000000   0.834496
# normalized_new_price               1.000000    0.834496   1.000000
# used_price                         0.834496    1.000000   0.834496
# new_price                          1.000000    0.834496   1.000000

# %%
# look for missing values
sns.heatmap(df.isnull(), cbar = False).set_title("Missing values heatmap")
# Out:
# Text(0.5, 1.0, 'Missing values heatmap')

# %%
# lets see what's up all those missing values from "rear_camera_mp"
df_nans = df[df['rear_camera_mp'].isna()]
df_nans
# Out:
#      device_brand       os  screen_size   4g  5g  rear_camera_mp  \
# 59        Infinix  Android        17.32  yes  no             NaN
# 60        Infinix  Android        15.39  yes  no             NaN
# 61        Infinix  Android        15.39  yes  no             NaN
# 62        Infinix  Android        15.39  yes  no             NaN
# 63        Infinix  Android        15.29  yes  no             NaN
# ...           ...      ...          ...  ...  ..             ...
# 3411       Realme  Android        15.34  yes  no             NaN
# 3412       Realme  Android        15.32  yes  no             NaN
# 3413       Realme  Android        15.32  yes  no             NaN
# 3448         Asus  Android        16.74  yes  no             NaN
# 3449         Asus  Android        15.34  yes  no             NaN
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 59                8.0             32.0  2.0   6000.0   209.0          2020
# 60                8.0             64.0  4.0   5000.0   185.0          2020
# 61                8.0             32.0  2.0   5000.0   185.0          2020
# 62               16.0             32.0  3.0   4000.0   178.0          2019
# 63               16.0             32.0  2.0   4000.0   165.0          2019
# ...               ...              ...  ...      ...     ...           ...
# 3411             16.0             64.0  4.0   4000.0   183.0          2019
# 3412             16.0             64.0  4.0   4035.0   184.0          2019
# 3413             25.0             64.0  4.0   4045.0   172.0          2019
# 3448             24.0            128.0  8.0   6000.0   240.0          2019
# 3449              8.0             64.0  6.0   5000.0   190.0          2019
#
#       days_used  normalized_used_price  normalized_new_price  used_price  \
# 59          245               4.282068              4.597642  290.795249
# 60          173               4.363608              4.711780  296.332623
# 61          256               4.181439              4.505460  283.961541
# 62          316               4.555244              4.602166  309.346646
# 63          468               4.416670              4.871297  299.936031
# ...         ...                    ...                   ...         ...
# 3411        503               4.570475              5.159974  310.380972
# 3412        433               4.521027              5.074424  307.022972
# 3413        288               4.778199              4.966753  324.487473
# 3448        325               5.715316              7.059317  388.127090
# 3449        232               4.492337              6.483872  305.074631
#
#        new_price
# 59    312.225863
# 60    319.976974
# 61    305.965812
# 62    312.533071
# 63    330.809752
# ...          ...
# 3411  350.413863
# 3412  344.604102
# 3413  337.292201
# 3448  479.398210
# 3449  440.319719
#
# [179 rows x 17 columns]

# %%
df_nans['device_brand'].value_counts()
# Out:
# Realme        36
# Xiaomi        23
# Oppo          20
# Motorola      18
# OnePlus       17
# Meizu         15
# Vivo          14
# Infinix       10
# Sony           7
# ZTE            4
# Asus           4
# BlackBerry     4
# Coolpad        3
# Lava           2
# Panasonic      2
# Name: device_brand, dtype: int64

# %%
df['device_brand'].value_counts()
# Out:
# Others        502
# Samsung       341
# Huawei        251
# LG            201
# Lenovo        171
# ZTE           140
# Xiaomi        132
# Oppo          129
# Asus          122
# Alcatel       121
# Micromax      117
# Vivo          117
# Honor         116
# HTC           110
# Nokia         106
# Motorola      106
# Sony           86
# Meizu          62
# Gionee         56
# Acer           51
# XOLO           49
# Panasonic      47
# Realme         41
# Apple          39
# Lava           36
# Celkon         33
# Spice          30
# Karbonn        29
# Coolpad        22
# BlackBerry     22
# Microsoft      22
# OnePlus        22
# Google         15
# Infinix        10
# Name: device_brand, dtype: int64

# %%
df_nans['os'].value_counts()
# Out:
# Android    179
# Name: os, dtype: int64

# %%
df['os'].value_counts()
# Out:
# Android    3214
# Others      137
# Windows      67
# iOS          36
# Name: os, dtype: int64

# %%
df_nans.describe()
# Out:
#        screen_size  rear_camera_mp  front_camera_mp  internal_memory  \
# count   179.000000             0.0       179.000000       179.000000
# mean     15.845587             NaN        15.458101       102.793296
# std       0.973714             NaN         7.717788        62.725877
# min      10.290000             NaN         5.000000        32.000000
# 25%      15.340000             NaN         8.000000        64.000000
# 50%      15.390000             NaN        16.000000       128.000000
# 75%      16.640000             NaN        16.000000       128.000000
# max      17.810000             NaN        32.000000       256.000000
#
#               ram      battery      weight  release_year   days_used  \
# count  179.000000   179.000000  179.000000    179.000000  179.000000
# mean     5.480447  4304.134078  189.718436   2019.603352  287.117318
# std      2.450271   589.947345   18.008417      0.648412  129.705642
# min      2.000000  2870.000000  150.000000   2017.000000   91.000000
# 25%      4.000000  4000.000000  178.000000   2019.000000  194.500000
# 50%      6.000000  4200.000000  190.200000   2020.000000  273.000000
# 75%      8.000000  5000.000000  202.500000   2020.000000  348.500000
# max     12.000000  6000.000000  253.000000   2020.000000  875.000000
#
#        normalized_used_price  normalized_new_price  used_price   new_price
# count             179.000000            179.000000  179.000000  179.000000
# mean                4.841868              5.590709  328.811273  379.665032
# std                 0.467409              0.707187   31.741741   48.025074
# min                 2.667228              3.690877  181.131468  250.647488
# 25%                 4.538136              5.036699  308.184809  342.042207
# 50%                 4.852499              5.602672  329.533201  380.477467
# 75%                 5.131098              6.183497  348.452881  419.921265
# max                 5.792038              7.090785  393.337268  481.535204

# %%
df_nans.describe(include=['object'])
# Out:
#        device_brand       os   4g   5g
# count           179      179  179  179
# unique           15        1    1    2
# top          Realme  Android  yes   no
# freq             36      179  179  112

# %%
# the "front_camera_mp" and "release_year" seem to have high correlation with 'rear_camera_mp', where the Nan values are
# lets see if we can see some pattern and use it to replace the NaN values of 'rear_camera_mp' instead of deleting them
pd.plotting.scatter_matrix(df[['rear_camera_mp','front_camera_mp','release_year']], figsize=(12, 8))
# Out:
# array([[<AxesSubplot: xlabel='rear_camera_mp', ylabel='rear_camera_mp'>,
#         <AxesSubplot: xlabel='front_camera_mp', ylabel='rear_camera_mp'>,
#         <AxesSubplot: xlabel='release_year', ylabel='rear_camera_mp'>],
#        [<AxesSubplot: xlabel='rear_camera_mp', ylabel='front_camera_mp'>,
#         <AxesSubplot: xlabel='front_camera_mp', ylabel='front_camera_mp'>,
#         <AxesSubplot: xlabel='release_year', ylabel='front_camera_mp'>],
#        [<AxesSubplot: xlabel='rear_camera_mp', ylabel='release_year'>,
#         <AxesSubplot: xlabel='front_camera_mp', ylabel='release_year'>,
#         <AxesSubplot: xlabel='release_year', ylabel='release_year'>]],
#       dtype=object)

# %%
# We could remove the Nan valued phones from the set, as there doesn't seem to be a reason to think this would create a bias in the subsiquently cleaned of NaNs dataset

# %%
df.dropna(inplace=True)
df.reset_index(inplace=True)

# %%
df.isnull().sum()
# Out:
# index                       0
# device_brand                0
# os                          0
# screen_size                 0
# 4g                          0
# 5g                          0
# rear_camera_mp              0
# front_camera_mp             0
# internal_memory             0
# ram                         0
# battery                     0
# weight                      0
# release_year                0
# days_used                   0
# normalized_used_price       0
# normalized_new_price        0
# used_price                  0
# new_price                   0
# cat_price                   0
# release_year_generalized    0
# dtype: int64

# %%
df["release_year"].value_counts()
# Out:
# 2014    611
# 2013    542
# 2015    487
# 2019    382
# 2016    368
# 2018    296
# 2017    285
# 2020    140
# 2022      1
# Name: release_year, dtype: int64

# %%
df.drop(df[df.release_year == 2022].index, inplace=True)

# %%
df["release_year"].value_counts()
# Out:
# 2014    611
# 2013    542
# 2015    487
# 2019    382
# 2016    368
# 2018    296
# 2017    285
# 2020    140
# Name: release_year, dtype: int64

# %% [markdown]
# ## Preliminary data analisys stage

# %%
sns.heatmap(df.corr(), 
        xticklabels=df.corr().columns,
        yticklabels=df.corr().columns)
# Out:
# C:\Users\Smelly_Giraffe\AppData\Local\Temp\ipykernel_16808\238410793.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# C:\Users\Smelly_Giraffe\AppData\Local\Temp\ipykernel_16808\238410793.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# C:\Users\Smelly_Giraffe\AppData\Local\Temp\ipykernel_16808\238410793.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <AxesSubplot: >

# %%
df.corr()
# Out:
# C:\Users\Smelly_Giraffe\AppData\Local\Temp\ipykernel_16808\1134722465.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                           index  screen_size  rear_camera_mp  front_camera_mp  \
# index                  1.000000    -0.055239        0.131314         0.084492
# screen_size           -0.055239     1.000000        0.272790         0.408981
# rear_camera_mp         0.131314     0.272790        1.000000         0.420815
# front_camera_mp        0.084492     0.408981        0.420815         1.000000
# internal_memory        0.000338     0.060698        0.004662         0.267196
# ram                    0.113558     0.345305        0.256221         0.419299
# battery               -0.020596     0.760397        0.378587         0.504392
# weight                -0.079350     0.745306       -0.032629         0.093591
# release_year          -0.020350     0.465400        0.358206         0.692046
# days_used              0.045468    -0.354782       -0.143614        -0.528170
# normalized_used_price  0.076084     0.630717        0.624892         0.628918
# normalized_new_price   0.061900     0.466969        0.562522         0.483888
# used_price             0.076084     0.630717        0.624892         0.628918
# new_price              0.061900     0.466969        0.562522         0.483888
# price_ratio            0.032730     0.328692        0.150296         0.267812
#
#                        internal_memory       ram   battery    weight  \
# index                         0.000338  0.113558 -0.020596 -0.079350
# screen_size                   0.060698  0.345305  0.760397  0.745306
# rear_camera_mp                0.004662  0.256221  0.378587 -0.032629
# front_camera_mp               0.267196  0.419299  0.504392  0.093591
# internal_memory               1.000000  0.036878  0.109031  0.015722
# ram                           0.036878  1.000000  0.328226  0.143167
# battery                       0.109031  0.328226  1.000000  0.627371
# weight                        0.015722  0.143167  0.627371  1.000000
# release_year                  0.202538  0.272584  0.590204  0.140028
# days_used                    -0.215362 -0.226224 -0.418925 -0.125869
# normalized_used_price         0.146547  0.502032  0.644458  0.364803
# normalized_new_price          0.151502  0.507014  0.497346  0.248728
# used_price                    0.146547  0.502032  0.644458  0.364803
# new_price                     0.151502  0.507014  0.497346  0.248728
# price_ratio                  -0.020513  0.033421  0.295720  0.231512
#
#                        release_year  days_used  normalized_used_price  \
# index                     -0.020350   0.045468               0.076084
# screen_size                0.465400  -0.354782               0.630717
# rear_camera_mp             0.358206  -0.143614               0.624892
# front_camera_mp            0.692046  -0.528170               0.628918
# internal_memory            0.202538  -0.215362               0.146547
# ram                        0.272584  -0.226224               0.502032
# battery                    0.590204  -0.418925               0.644458
# weight                     0.140028  -0.125869               0.364803
# release_year               1.000000  -0.709702               0.522939
# days_used                 -0.709702   1.000000              -0.339668
# normalized_used_price      0.522939  -0.339668               1.000000
# normalized_new_price       0.305595  -0.197723               0.829483
# used_price                 0.522939  -0.339668               1.000000
# new_price                  0.305595  -0.197723               0.829483
# price_ratio                0.402720  -0.257912               0.366362
#
#                        normalized_new_price  used_price  new_price  \
# index                              0.061900    0.076084   0.061900
# screen_size                        0.466969    0.630717   0.466969
# rear_camera_mp                     0.562522    0.624892   0.562522
# front_camera_mp                    0.483888    0.628918   0.483888
# internal_memory                    0.151502    0.146547   0.151502
# ram                                0.507014    0.502032   0.507014
# battery                            0.497346    0.644458   0.497346
# weight                             0.248728    0.364803   0.248728
# release_year                       0.305595    0.522939   0.305595
# days_used                         -0.197723   -0.339668  -0.197723
# normalized_used_price              0.829483    1.000000   0.829483
# normalized_new_price               1.000000    0.829483   1.000000
# used_price                         0.829483    1.000000   0.829483
# new_price                          1.000000    0.829483   1.000000
# price_ratio                       -0.209246    0.366362  -0.209246
#
#                        price_ratio
# index                     0.032730
# screen_size               0.328692
# rear_camera_mp            0.150296
# front_camera_mp           0.267812
# internal_memory          -0.020513
# ram                       0.033421
# battery                   0.295720
# weight                    0.231512
# release_year              0.402720
# days_used                -0.257912
# normalized_used_price     0.366362
# normalized_new_price     -0.209246
# used_price                0.366362
# new_price                -0.209246
# price_ratio               1.000000

# %%
fig = pd.plotting.scatter_matrix(df, figsize=(12, 8))

for ax in fig.ravel():
    ax.set_xlabel(ax.get_xlabel(), fontsize = 10, rotation = 90)
    ax.set_ylabel(ax.get_ylabel(), fontsize = 10, rotation = 0)

# %%
df['cat_price'], cut_bin = pd.qcut(df['used_price'], q = 5, labels = ['1', '2', '3', '4', '5'], retbins = True)
df.head()

df_cat = df[['ram','os','4g','5g','release_year','cat_price']].copy()

# %%
df_cat
# Out:
#       ram       os   4g   5g  release_year cat_price
# 0     3.0  Android  yes   no          2020         3
# 1     8.0  Android  yes  yes          2020         5
# 2     8.0  Android  yes  yes          2020         5
# 3     3.0  Android  yes   no          2020         3
# 4     4.0  Android  yes   no          2020         3
# ...   ...      ...  ...  ...           ...       ...
# 3107  4.0      iOS  yes   no          2019         5
# 3108  8.0  Android  yes   no          2018         5
# 3109  3.0  Android  yes   no          2020         3
# 3110  2.0  Android  yes   no          2020         3
# 3111  2.0  Android  yes   no          2020         2
#
# [3111 rows x 6 columns]

# %%
df_cat['os'] = df_cat['os'].apply(lambda x: '0' if x == 'Android' else '1')
df_cat['4g'] = df['4g'].apply(lambda x: '0' if x == 'no' else '1')
df_cat['5g'] = df['5g'].apply(lambda x: '0' if x == 'no' else '1')

# %%
df_cat = df_cat.astype(float)

# %%
fig, axes = plt.subplots(3, 4, figsize=(16,8))
fig.suptitle('Barplots')

i = 0
for col in df_cat.columns:
    sns.barplot(ax = axes[i//4,i%4], y=col, x='cat_price', data=df_cat, errorbar = "sd", capsize = 0.1, estimator=np.mean)  
    i = i + 1
    # graph1.axhline(1.0, linestyle="dashed")

# %% [markdown]
# # Notes
#
# ### Distibution of prices
# * Nice distribution (check if its poisson or gauss or else)
# * Battery distribution
# * Used price vs year - some trend
# * Ram vs year - maybe something there
# * Double plot for year distribution (with hue for has or has not 5G)
# * Days used
#
# ### Functional correlations
# * Old vs. New price - good linear correlation
# * Rear_camera_MP vs Price - maybe something there
# * Screen size vs battery - maybe something there
# * Screen size vs weight - maybe something there
# * Ram vs price - appears to increase on average
#
# ### Other
#
# * Battery vs used price has some funny splitting - check battery vs used price scatters, with hues

# %% [markdown]
# ### Data analisys stage

# %%
sns.scatterplot(y='battery', x='normalized_used_price', hue='os', data=df)
# Out:
# <AxesSubplot: xlabel='normalized_used_price', ylabel='battery'>

# %%
sns.scatterplot(y='battery', x='normalized_used_price', hue='release_year', data=df)
# Out:
# <AxesSubplot: xlabel='normalized_used_price', ylabel='battery'>

# %%
sns.scatterplot(y='rear_camera_mp', x='normalized_used_price', hue='os', data=df)
# Out:
# <AxesSubplot: xlabel='normalized_used_price', ylabel='rear_camera_mp'>

# %%
sns.scatterplot(y='battery', x='screen_size', hue='release_year', data=df)
# Out:
# <AxesSubplot: xlabel='screen_size', ylabel='battery'>

# %%
sns.scatterplot(y='battery', x='screen_size', hue='release_year', data=df[df['release_year'] == 2015])
# Out:
# <AxesSubplot: xlabel='screen_size', ylabel='battery'>

# %%
sns.scatterplot(y='battery', x='screen_size', hue='release_year', data=df[df['release_year'] == 2020])
# Out:
# <AxesSubplot: xlabel='screen_size', ylabel='battery'>

# %%
# df['release_year_generalized'] = df['release_year'].apply(lambda x: '2013 & 2014' if x == '2013' or '2014' else x)
# df['release_year_generalized'] = df['release_year'].apply(lambda x: '2015 & 2016' if x == '2015' or '2016' else x)
# df['release_year_generalized'] = df['release_year'].apply(lambda x: '2017 & 2018' if x == '2017' or '2018' else x)
# df['release_year_generalized'] = df['release_year'].apply(lambda x: '2019 & 2020' if x == '2019' or '2020' else x)

new_series = []
for index, row in df[['release_year']].iterrows():
    x = row[0]
    if x == 2013 or x == 2014:
        new_series.append('2013 & 2014')
    elif x == 2015 or x == 2016:
        new_series.append('2015 & 2016')
    elif x == 2017 or x == 2018:
        new_series.append('2017 & 2018')
    elif x == 2019 or x == 2020:
        new_series.append('2019 & 2020')
    else:
        new_series.append('2021 & 2022')

# %%
df['release_year_generalized'] = new_series

# %%
plt.figure(figsize=(9, 6), dpi=100) # width and height in inches
plot = sns.kdeplot(
   data=df, x="screen_size", hue="release_year_generalized",
   fill=True, common_norm=False, palette="tab10",
   alpha=.5, linewidth=0, warn_singular=False
)
plot.set_xlabel("Screen size (cm)",fontsize=25)
plot.set_ylabel("Density",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('KDE_of_screen_size_by_year.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='release_year', y='screen_size', data=df, linewidth=3, markers=True) 
plot.set_xlabel("Year released", fontsize=25)
plot.set_ylabel("Screen size (cm)", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('year_vs_screen_size.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='release_year', y='battery', data=df, linewidth=3, markers=True) 
plot.set_xlabel("Year released", fontsize=25)
plot.set_ylabel("Battery capacity (mAh)", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('year_vs_battery.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
sns.boxplot(x='release_year', y='screen_size', data=df)
# Out:
# <AxesSubplot: xlabel='release_year', ylabel='screen_size'>

# %%
sns.lineplot(x='release_year', y='ram', data=df)
# Out:
# <AxesSubplot: xlabel='release_year', ylabel='ram'>

# %%
sns.boxplot(x='release_year', y='ram', data=df)
# Out:
# <AxesSubplot: xlabel='release_year', ylabel='ram'>

# %%
df
# Out:
#       index device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0         0        Honor  Android        14.50  yes   no            13.0
# 1         1        Honor  Android        17.30  yes  yes            13.0
# 2         2        Honor  Android        16.69  yes  yes            13.0
# 3         4        Honor  Android        15.32  yes   no            13.0
# 4         5        Honor  Android        16.23  yes   no            13.0
# ...     ...          ...      ...          ...  ...  ...             ...
# 3107   3447        Apple      iOS        15.27  yes   no             8.0
# 3108   3450         Asus  Android        15.24  yes   no            13.0
# 3109   3451      Alcatel  Android        15.80  yes   no            13.0
# 3110   3452      Alcatel  Android        15.80  yes   no            13.0
# 3111   3453      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  ...  weight  release_year  \
# 0                 5.0             64.0  3.0  ...   146.0          2020
# 1                16.0            128.0  8.0  ...   213.0          2020
# 2                 8.0            128.0  8.0  ...   213.0          2020
# 3                 8.0             64.0  3.0  ...   185.0          2020
# 4                 8.0             64.0  4.0  ...   176.0          2020
# ...               ...              ...  ...  ...     ...           ...
# 3107              7.0             64.0  4.0  ...   194.0          2019
# 3108              8.0            128.0  8.0  ...   200.0          2018
# 3109              5.0             32.0  3.0  ...   165.0          2020
# 3110              5.0             32.0  2.0  ...   160.0          2020
# 3111              5.0             16.0  2.0  ...   168.0          2020
#
#       days_used  normalized_used_price  normalized_new_price  used_price  \
# 0           127               4.307572              4.715100  292.527245
# 1           325               5.162097              5.519018  350.557983
# 2           162               5.111084              5.884631  347.093698
# 3           293               4.389995              4.947837  298.124547
# 4           223               4.413889              5.060694  299.747175
# ...         ...                    ...                   ...         ...
# 3107        208               5.100902              6.287933  346.402287
# 3108        541               5.037732              6.251538  342.112348
# 3109        201               4.357350              4.528829  295.907615
# 3110        149               4.349762              4.624188  295.392315
# 3111        176               4.132122              4.279994  280.612400
#
#        new_price  cat_price release_year_generalized price_ratio
# 0     320.202458          3              2019 & 2020    0.913570
# 1     374.796508          5              2019 & 2020    0.935329
# 2     399.625272          5              2019 & 2020    0.868548
# 3     336.007643          3              2019 & 2020    0.887255
# 4     343.671763          3              2019 & 2020    0.872190
# ...          ...        ...                      ...         ...
# 3107  427.013524          5              2019 & 2020    0.811221
# 3108  424.541927          5              2017 & 2018    0.805839
# 3109  307.552774          3              2019 & 2020    0.962136
# 3110  314.028620          3              2019 & 2020    0.940654
# 3111  290.654386          2              2019 & 2020    0.965450
#
# [3111 rows x 21 columns]

# %%
df["4g"].value_counts()
# Out:
# yes    2058
# no     1053
# Name: 4g, dtype: int64

# %%
df["5g"].value_counts()
# Out:
# no     3031
# yes      80
# Name: 5g, dtype: int64

# %%
df["release_year"].value_counts()
# Out:
# 2014    611
# 2013    542
# 2015    487
# 2019    382
# 2016    368
# 2018    296
# 2017    285
# 2020    140
# Name: release_year, dtype: int64

# %%
df_used = df[['release_year','days_used','used_price']].copy()
df_used['new_or_used'] = "Used"
df_used.rename(columns={"used_price":'price'}, inplace=True)

df_new = df[['release_year','days_used','new_price']].copy()
df_new['new_or_used'] = "New"
df_new.rename(columns={"new_price":'price'}, inplace=True)

df_tot = pd.concat([df_used, df_new])
df_tot
# Out:
#       release_year  days_used       price new_or_used
# 0             2020        127  292.527245        Used
# 1             2020        325  350.557983        Used
# 2             2020        162  347.093698        Used
# 3             2020        293  298.124547        Used
# 4             2020        223  299.747175        Used
# ...            ...        ...         ...         ...
# 3107          2019        208  427.013524         New
# 3108          2018        541  424.541927         New
# 3109          2020        201  307.552774         New
# 3110          2020        149  314.028620         New
# 3111          2020        176  290.654386         New
#
# [6222 rows x 4 columns]

# %%
plt.figure(figsize=(12, 6), dpi=100) # width and height in inches
plot = sns.barplot(x='release_year', y='price', hue='new_or_used', data=df_tot)
plot.set_xlabel("Year released",fontsize=25)
plot.set_ylabel("Price",fontsize=25)
plot.tick_params(labelsize=17)
sns.move_legend(plot, "lower right", bbox_to_anchor=(1, 1))
plt.savefig('Price_vs_Year_double_barplot.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df['price_ratio'] = 100*df['used_price']/df['new_price']

# %%
df['price_ratio']
# Out:
# 0       91.356964
# 1       93.532884
# 2       86.854792
# 3       88.725525
# 4       87.219029
#           ...
# 3107    81.122088
# 3108    80.583878
# 3109    96.213606
# 3110    94.065412
# 3111    96.545042
# Name: price_ratio, Length: 3111, dtype: float64

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='release_year', y='price_ratio', data=df, linewidth=3, markers=True) 
plot.set_xlabel("Year released", fontsize=25)
plot.set_ylabel("Old to new price ratio (%)", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('new_to_old_price_ratio.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(7, 6), dpi=100) # width and height in inches
plot = sns.histplot(data=df_tot, x='price', hue='new_or_used', kde=True)  
plot.set_xlabel("Price (in USD)",fontsize=25)
plot.set_ylabel("#",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('histograms_of_prices.png', transparent=True, bbox_inches='tight')
plt.show() 

# the mediam of the used is 296 +- 40
# the median of the new is 355 +- 46

# %%
plt.figure(figsize=(7, 6), dpi=100) # width and height in inches
plot = sns.histplot(data=df, x='battery', bins=12, kde=False)  
plot.set_xlabel("Battery capacity (mAh)",fontsize=25)
plot.set_ylabel("#",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('histograms_of_battery.png', transparent=True, bbox_inches='tight')
plt.show() 

# mean

# %%
df.battery[(df.battery >= 1700) & (df.battery <= 4100)].count()/df.battery.count()
# Out:
# 0.8129218900675024

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='release_year', y='ram', data=df, linewidth=3, markers=True) 
plot.set_xlabel("Year released", fontsize=25)
plot.set_ylabel("RAM (GB)", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('ram_vs_year.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=100) # width and height in inches
plot = sns.barplot(x='release_year', y='used_price', hue='4g', data=df)
plot.set_xlabel("Year released",fontsize=25)
plot.set_ylabel("Price",fontsize=25)
plot.tick_params(labelsize=17)
sns.move_legend(plot, "lower right", bbox_to_anchor=(1, 1))
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=100) # width and height in inches
plot = sns.scatterplot(x='days_used', y='used_price', data=df)
plot.set_xlabel("days_used",fontsize=25)
plot.set_ylabel("Price",fontsize=25)
plot.tick_params(labelsize=17)
# sns.move_legend(plot, "lower right", bbox_to_anchor=(1, 1))
plt.savefig('foo.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df.used_price[df.days_used <= 500].mean()
# Out:
# 322.23145952307584

# %%
df.used_price[df.days_used >= 500].mean()
# Out:
# 286.1424547110559

# %%
#df['years_used'], cut_bin = pd.qcut(df['days_used'], q = 7, labels = ['0.5', '1', '1.5', '2', '2.5', '3', '3.5'], retbins = True)

df['years_used'] = pd.cut(df.days_used, 6, labels=['0.5', '1', '1.5', '2', '2.5', '3'])

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='years_used', y='used_price', data=df, linewidth=3, markers=True) 
plot.set_xlabel("Years used", fontsize=25)
plot.set_ylabel("Price", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('price_vs_years_used.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
280/323
# Out:
# 0.8668730650154799

# %%
plt.figure(figsize=(7, 6), dpi=100) # width and height in inches
plot = sns.histplot(data=df, x='days_used', kde=False)  
plot.set_xlabel("Days used",fontsize=25)
plot.set_ylabel("#",fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('days_used_hist.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_tot
# Out:
#       release_year  days_used       price new_or_used
# 0             2020        127  292.527245        Used
# 1             2020        325  350.557983        Used
# 2             2020        162  347.093698        Used
# 3             2020        293  298.124547        Used
# 4             2020        223  299.747175        Used
# ...            ...        ...         ...         ...
# 3107          2019        208  427.013524         New
# 3108          2018        541  424.541927         New
# 3109          2020        201  307.552774         New
# 3110          2020        149  314.028620         New
# 3111          2020        176  290.654386         New
#
# [6222 rows x 4 columns]

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.lineplot(x='release_year', y='weight', data=df, linewidth=3, markers=True) 
plot.set_xlabel("Year released", fontsize=25)
plot.set_ylabel("Weight (g)", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('weight_vs_year', transparent=True, bbox_inches='tight')
plt.show()

# %%
189/162
# Out:
# 1.1666666666666667

# %%
df
# Out:
#       index device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0         0        Honor  Android        14.50  yes   no            13.0
# 1         1        Honor  Android        17.30  yes  yes            13.0
# 2         2        Honor  Android        16.69  yes  yes            13.0
# 3         4        Honor  Android        15.32  yes   no            13.0
# 4         5        Honor  Android        16.23  yes   no            13.0
# ...     ...          ...      ...          ...  ...  ...             ...
# 3107   3447        Apple      iOS        15.27  yes   no             8.0
# 3108   3450         Asus  Android        15.24  yes   no            13.0
# 3109   3451      Alcatel  Android        15.80  yes   no            13.0
# 3110   3452      Alcatel  Android        15.80  yes   no            13.0
# 3111   3453      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  ...  release_year  days_used  \
# 0                 5.0             64.0  3.0  ...          2020        127
# 1                16.0            128.0  8.0  ...          2020        325
# 2                 8.0            128.0  8.0  ...          2020        162
# 3                 8.0             64.0  3.0  ...          2020        293
# 4                 8.0             64.0  4.0  ...          2020        223
# ...               ...              ...  ...  ...           ...        ...
# 3107              7.0             64.0  4.0  ...          2019        208
# 3108              8.0            128.0  8.0  ...          2018        541
# 3109              5.0             32.0  3.0  ...          2020        201
# 3110              5.0             32.0  2.0  ...          2020        149
# 3111              5.0             16.0  2.0  ...          2020        176
#
#       normalized_used_price  normalized_new_price  used_price   new_price  \
# 0                  4.307572              4.715100  292.527245  320.202458
# 1                  5.162097              5.519018  350.557983  374.796508
# 2                  5.111084              5.884631  347.093698  399.625272
# 3                  4.389995              4.947837  298.124547  336.007643
# 4                  4.413889              5.060694  299.747175  343.671763
# ...                     ...                   ...         ...         ...
# 3107               5.100902              6.287933  346.402287  427.013524
# 3108               5.037732              6.251538  342.112348  424.541927
# 3109               4.357350              4.528829  295.907615  307.552774
# 3110               4.349762              4.624188  295.392315  314.028620
# 3111               4.132122              4.279994  280.612400  290.654386
#
#       cat_price  release_year_generalized price_ratio years_used
# 0             3               2019 & 2020   91.356964        0.5
# 1             5               2019 & 2020   93.532884          1
# 2             5               2019 & 2020   86.854792        0.5
# 3             3               2019 & 2020   88.725525          1
# 4             3               2019 & 2020   87.219029        0.5
# ...         ...                       ...         ...        ...
# 3107          5               2019 & 2020   81.122088        0.5
# 3108          5               2017 & 2018   80.583878        1.5
# 3109          3               2019 & 2020   96.213606        0.5
# 3110          3               2019 & 2020   94.065412        0.5
# 3111          2               2019 & 2020   96.545042        0.5
#
# [3111 rows x 22 columns]

# %%
# plt.figure(figsize=(9, 6), dpi = 100)
# plot = sns.scatterplot(x='rear_camera_mp', y='used_price', data=df, linewidth=3, markers=True) 
# plot.set_xlabel("Year released", fontsize=25)
# plot.set_ylabel("Weight (g)", fontsize=25)
# plot.tick_params(labelsize=17)
# plt.savefig('camera_vs_price', transparent=True, bbox_inches='tight')
# plt.show()

# %%
plt.figure(figsize=(10, 5), dpi=120) # width and height in inches
plot = sns.barplot(x='release_year', y='used_price', hue='os', data=df, errorbar = None, capsize = 0.05, estimator=np.mean)
plot.set_xlabel("Year released",fontsize=25)
plot.set_ylabel("Price",fontsize=25)
plot.tick_params(labelsize=17)
sns.move_legend(plot, "lower right")
plt.savefig('price_by_year_by-OS.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
df.os.value_counts()
# Out:
# Android    2899
# Others      124
# Windows      64
# iOS          24
# Name: os, dtype: int64

# %%
plt.figure(figsize=(9, 6), dpi = 100)
plot = sns.regplot(x='new_price', y='used_price', data=df) 
plot.set_xlabel("Year released", fontsize=25)
plot.set_ylabel("Weight (g)", fontsize=25)
plot.tick_params(labelsize=17)
plt.savefig('camera_vs_price', transparent=True, bbox_inches='tight')
plt.show()

# %%
df_modified = df[df.os == 'Android'].drop(['device_brand','4g','5g','os','index','years_used','release_year_generalized','normalized_new_price','normalized_used_price','price_ratio', 'cat_price'], axis=1)

# %%
df_modified
# Out:
#       screen_size  rear_camera_mp  front_camera_mp  internal_memory  ram  \
# 0           14.50            13.0              5.0             64.0  3.0
# 1           17.30            13.0             16.0            128.0  8.0
# 2           16.69            13.0              8.0            128.0  8.0
# 3           15.32            13.0              8.0             64.0  3.0
# 4           16.23            13.0              8.0             64.0  4.0
# ...           ...             ...              ...              ...  ...
# 3103        14.81             8.0              5.0             32.0  2.0
# 3108        15.24            13.0              8.0            128.0  8.0
# 3109        15.80            13.0              5.0             32.0  3.0
# 3110        15.80            13.0              5.0             32.0  2.0
# 3111        12.83            13.0              5.0             16.0  2.0
#
#       battery  weight  release_year  days_used  used_price   new_price
# 0      3020.0   146.0          2020        127  292.527245  320.202458
# 1      4300.0   213.0          2020        325  350.557983  374.796508
# 2      4200.0   213.0          2020        162  347.093698  399.625272
# 3      5000.0   185.0          2020        293  298.124547  336.007643
# 4      4000.0   176.0          2020        223  299.747175  343.671763
# ...       ...     ...           ...        ...         ...         ...
# 3103   3000.0   141.0          2019        383  284.632543  292.636895
# 3108   4000.0   200.0          2018        541  342.112348  424.541927
# 3109   4000.0   165.0          2020        201  295.907615  307.552774
# 3110   4000.0   160.0          2020        149  295.392315  314.028620
# 3111   4000.0   168.0          2020        176  280.612400  290.654386
#
# [2899 rows x 11 columns]

# %%
df_modified.to_csv("data_prepared_for_ML.csv", index=False)
