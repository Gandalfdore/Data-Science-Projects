# %% [markdown]
# # Data mining of statistics from OECD on the countries of USA and Spain

# %% [markdown]
# **Source: https://data.oecd.org/**

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib3
import ssl
import re

# %% [markdown]
# **In case that the server doesn't support "RFC 5746 secure renegotiation" and the client is using OpenSSL 3, one needs to:**
#
# Source: https://stackoverflow.com/questions/71603314/ssl-error-unsafe-legacy-renegotiation-disabled

# %%
class CustomHttpAdapter (requests.adapters.HTTPAdapter):
    # "Transport adapter" that allows us to use custom ssl_context.

    def __init__(self, ssl_context=None, **kwargs):
        self.ssl_context = ssl_context
        super().__init__(**kwargs)

    def init_poolmanager(self, connections, maxsize, block=False):
        self.poolmanager = urllib3.poolmanager.PoolManager(
            num_pools=connections, maxsize=maxsize,
            block=block, ssl_context=self.ssl_context)


def get_legacy_session():
    ctx = ssl.create_default_context(ssl.Purpose.SERVER_AUTH)
    ctx.options |= 0x4  # OP_LEGACY_SERVER_CONNECT
    session = requests.session()
    session.mount('https://', CustomHttpAdapter(ctx))
    return session

# %%
# get the URLs
url_usa = "https://data.oecd.org/united-states.htm" 
url_spain = "https://data.oecd.org/spain.htm"

# %%
# get the html data
html_data_usa = get_legacy_session().get(url_usa).text
html_data_spain  = get_legacy_session().get(url_spain).text

# %%
# the beautiful soup data
soup_usa = BeautifulSoup(html_data_usa, 'html')
soup_spain = BeautifulSoup(html_data_spain, 'html')

# %%
def table_reader(soup_object, country = str):
    """This function takkes the soup object and picks the entries desired."""
    
    i = 0
    table = {}
    headline = []

    for table_i in soup_object.find_all('table'):
        i += 1

        for row in table_i.find("thead").find_all('tr'):
            title = row.find("span").text
            table[i] = pd.DataFrame(columns=["Topic", "Data for {0}".format(country), "Details for {0}".format(country)])
            headline.append(title)

        for row in table_i.find("tbody").find_all('tr'):
            col = row.find_all("td")
            col0_main_entry = col[0].find("a")
            topic = col0_main_entry.find("span").text
            
            col2_main_entry = col[2].find_all('span')
            if len(col2_main_entry) == 0:
                data = 0
                details = 0
            else:
                data = col2_main_entry[0].text
                details = col2_main_entry[2].text

            table[i].loc[len(table[i])] = [topic, data, details]
            
    return headline, table

# %%
# get the tables
headlines_usa, tables_usa = table_reader(soup_usa,'USA')
headlines_spain, tables_spain = table_reader(soup_spain,'Spain')

# %%
headlines_spain[11]
# Out:
# ' Society'

# %%
tables_spain[12]
# Out:
#                               Topic Data for Spain  \
# 0                   Fertility rates           1.36
# 1  National population distribution           48.7
# 2       Permanent immigrant inflows      349 794.0
# 3                      Poverty rate           0.15
# 4                   Social spending           28.1
#
#                             Details for Spain
# 0      \nTotal\nChildren/woman\n2020\nSpain\n
# 1  \nUrban regions\nPercentage\n2014\nSpain\n
# 2              \nTotal\nNumber\n2019\nSpain\n
# 3               \nTotal\nRatio\n2019\nSpain\n
# 4           \nPublic\n% of GDP\n2022\nSpain\n

# %%
def table_unificator(table1, table2):
    """This function put the tables together."""

    new_table = table1.drop(table1.columns[[0]], axis=1)
    table2 = table2.join(new_table)

    return table2

# %%
def pipeline(headlines_spain, headlines_usa, tables_spain, tables_usa):
    """This is a pipeline to put it all together (all the different tables) in one big dataframe."""
    
    for i in range(len(headlines_spain)):
        
        # for 1 common table
        table_x = tables_spain[i+1] 
        table_y = tables_usa[i+1]
        table_z = table_unificator(table_x, table_y)
        
        # adding a title column
        new_col = [headlines_spain[i]] + (table_z.shape[0]-1)*['Nan'] 
        table_z.insert(loc=0, column="Table", value=new_col)
        # now the coomon table is done
        
        if i == 0:
            df = table_z
        else:
            df = pd.concat([df,table_z])
    
    return df

# %%
df = pipeline(headlines_spain, headlines_usa, tables_spain, tables_usa)
df
# Out:
#                         Table  \
# 0                 Agriculture
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                 Development
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                     Economy
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                   Education
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                      Energy
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                 Environment
# 1                         Nan
# 2                         Nan
# 0                     Finance
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                  Government
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                      Health
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0   Innovation and Technology
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                        Jobs
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
# 0                     Society
# 1                         Nan
# 2                         Nan
# 3                         Nan
# 4                         Nan
#
#                                                Topic       Data for USA  \
# 0                                  Agricultural land         265 266.27
# 1                               Agricultural support               10.5
# 2                                    Crop production               3.61
# 3                                      Fish landings        4 161 177.0
# 4                                   Nutrient balance               30.5
# 0                            Distribution of net ODA           11 808.8
# 1                Grants by private agencies and NGOs            4 953.0
# 2                                            Net ODA                0.2
# 3                                      Private flows          159 212.2
# 4                   Total official and private flows          229 521.9
# 0                  Composite leading indicator (CLI)              98.49
# 1                        Household disposable income               0.00
# 2                Labour compensation per hour worked                3.8
# 3                                Net national income             59 557
# 4                        Trade in goods and services               10.9
# 0                                 Education spending             35 347
# 1                     Mathematics performance (PISA)                482
# 2                         Reading performance (PISA)                494
# 3                         Science performance (PISA)                503
# 4  Youth not in employment, education or training...                9.3
# 0                               Crude oil production          559 454.7
# 1                          Infrastructure investment  92 033 898 305.08
# 2                                Passenger transport        6 558 301.0
# 3                              Primary energy supply               0.10
# 4                                     Road accidents                 13
# 0                              Air and GHG emissions               13.6
# 1                                    Municipal waste              811.5
# 2                                  Water withdrawals          387 242.0
# 0                                   Broad money (M3)             174.86
# 1                           Long-term interest rates                3.7
# 2                      Net pension replacement rates               50.5
# 3                                 Net pension wealth                8.8
# 4                          Short-term interest rates                4.9
# 0                        General government spending               44.9
# 1                                Government reserves           91 322.5
# 2                           Tax on corporate profits                1.6
# 3                                        Tax revenue               26.6
# 4                                          Tax wedge               28.4
# 0                                    Health spending             12 318
# 1                                      Hospital beds                2.8
# 2                            Length of hospital stay               5.40
# 3                           Life expectancy at birth               74.2
# 4                     Overweight or obese population               73.1
# 0                     Gross domestic spending on R&D                3.5
# 1                                    ICT value added                7.1
# 2                                    Internet access               81.8
# 3                     Mobile broadband subscriptions              171.6
# 4                            Triadic patent families           13 039.8
# 0                                      Average wages           74 737.8
# 1                                    Employment rate               71.4
# 2                                       Hours worked              1 791
# 3                        Long-term unemployment rate               23.1
# 4                               Self-employment rate                6.6
# 0                                    Fertility rates               1.64
# 1                   National population distribution               42.1
# 2                        Permanent immigrant inflows        1 030 990.0
# 3                                       Poverty rate               0.15
# 4                                    Social spending               22.7
#
#                                      Details for USA    Data for Spain  \
# 0  \nPermanent pasture\nThousand hectares\n2019\n...          7 495.98
# 1  \nProducer support (PSE)\n% of gross farm rece...                 0
# 2     \nWheat\nTonnes/hectare\n2030\nUnited States\n                 0
# 3  \nNational landings in domestic ports\nTonnes\...         312 781.2
# 4  \nNitrogen\nKilograms/hectare\n2019\nUnited St...              49.3
# 0  \nLeast developed countries\nMillion US dollar...             157.4
# 1  \nTotal\nMillion US dollars\n2021\nUnited Stat...               1.9
# 2  \nODA grant equivalent\n% of gross national in...               0.3
# 3  \nTotal\nMillion US dollars\n2021\nUnited Stat...           3 799.9
# 4  \nTotal\nMillion US dollars\n2021\nUnited Stat...           7 022.0
# 0  \nAmplitude adjusted\nLong-term average = 100\...             98.27
# 1  \nGross\nPer capita, percentage change, previo...             -2.76
# 2  \nTotal\nAnnual growth rate (%)\n2021\nUnited ...              -0.5
# 3  \nTotal\nUS dollars/capita\n2021\nUnited States\n            34 005
# 4         \nExports\n% of GDP\n2021\nUnited States\n              41.6
# 0  \nTertiary\nUS dollars/student\n2019\nUnited S...            14 237
# 1          \nBoys\nMean score\n2018\nUnited States\n               485
# 2          \nBoys\nMean score\n2018\nUnited States\n               485
# 3          \nBoys\nMean score\n2018\nUnited States\n               484
# 4  \n15-19 year-old men\n% in same age group\n202...               8.5
# 0       \nTotal\nThousand toe\n2021\nUnited States\n               5.9
# 1                \nRoad\nEuro\n2021\nUnited States\n  3 959 000 000.00
# 2  \nRoad\nMillion passenger-kilometres\n2017\nUn...         284 467.0
# 3  \nTotal\nToe/1 000 US dollars\n2021\nUnited St...              0.07
# 4  \nDeaths\nPer 1 000 000 inhabitants\n2021\nUni...                 3
# 0  \nCarbon dioxide (CO2)\nTonnes/capita\n2021\nU...               4.4
# 1   \nTotal\nKilograms/capita\n2018\nUnited States\n             472.8
# 2         \nTotal\nMillion m3\n2015\nUnited States\n          29 445.9
# 0       \nTotal\n2015=100\nFeb-2023\nUnited States\n                 0
# 1    \nTotal\n% per annum\nMar-2023\nUnited States\n               3.4
# 2  \nMen\n% of pre-retirement earnings\n2020\nUni...              80.3
# 3  \nMen\nMultiple of annual gross earnings\n2020...              16.0
# 4    \nTotal\n% per annum\nMar-2023\nUnited States\n               2.9
# 0           \nTotal\n% of GDP\n2021\nUnited States\n              50.6
# 1    \nTotal\nSDR millions\nQ4-2014\nUnited States\n          27 576.4
# 2           \nTotal\n% of GDP\n2021\nUnited States\n               2.7
# 3           \nTotal\n% of GDP\n2021\nUnited States\n              38.4
# 4   \nTotal\n% of labour cost\n2021\nUnited States\n              39.3
# 0  \nTotal\nUS dollars/capita\n2021\nUnited States\n             3 718
# 1  \nTotal\nPer 1 000 inhabitants\n2019\nUnited S...               3.0
# 2          \nAcute care\nDays\n2019\nUnited States\n              6.40
# 3                \nMen\nYears\n2020\nUnited States\n              80.3
# 4  \nMeasured\n% of population aged 15+\n2019\nUn...                 0
# 0           \nTotal\n% of GDP\n2021\nUnited States\n               1.4
# 1   \nTotal\n% of value added\n2011\nUnited States\n               4.6
# 2  \nTotal\n% of all households\n2021\nUnited Sta...              96.1
# 3  \nTotal\nPer 100 inhabitants\nQ2-2022\nUnited ...             109.9
# 4             \nTotal\nNumber\n2020\nUnited States\n             321.9
# 0         \nTotal\nUS dollars\n2021\nUnited States\n          39 202.3
# 1  \nTotal\n% of working age population\nQ4-2022\...              64.3
# 2       \nTotal\nHours/worker\n2021\nUnited States\n             1 641
# 3    \nTotal\n% of unemployed\n2021\nUnited States\n              41.7
# 4    \nTotal\n% of employment\n2021\nUnited States\n              15.8
# 0     \nTotal\nChildren/woman\n2020\nUnited States\n              1.36
# 1  \nUrban regions\nPercentage\n2014\nUnited Stat...              48.7
# 2             \nTotal\nNumber\n2019\nUnited States\n         349 794.0
# 3              \nTotal\nRatio\n2021\nUnited States\n              0.15
# 4          \nPublic\n% of GDP\n2021\nUnited States\n              28.1
